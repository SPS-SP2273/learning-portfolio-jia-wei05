# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='I am legend',                      # Provides data as input for x and y axes, label gives the label for legend
         color='red', linestyle='dashed')                  # Customises plotted line
plt.xlabel('x-values')
plt.ylabel('y-values')                                     # Labels for x and y axes
plt.title('X vs Y')                                        # Plot title
plt.grid(alpha=.9)                                         # Contrast of grid lines
plt.legend(loc='center')                                   # Location of legend

# %% [markdown]
# ## 1.2 Adding another plot

# %%
plt.plot(x, y_1, y_2)
# Out:
# [<matplotlib.lines.Line2D at 0x26801995a90>,
#  <matplotlib.lines.Line2D at 0x26801995bd0>]

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %% [markdown]
# # 2 Better with NumPy

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
import numpy as np
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-5, 5])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
